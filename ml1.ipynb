# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("Iris.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
X=df.drop(['species'],axis=1)
y=df['species']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
lda = LinearDiscriminantAnalysis()

# %%
X_lda = lda.fit_transform(X_scaled, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_lda, y, test_size=0.2, random_state=42)

# %%
classifier=LogisticRegression()
classifier.fit(X_train,y_train)
LogisticRegression()
# Out:
# LogisticRegression()

# %%
new_flower = [[6.7,3.0,5.2,2.3 ]]
new_flower_scaled = scaler.transform(new_flower)
new_flower_lda = lda.transform(new_flower_scaled)
predicted_species = classifier.predict(new_flower_lda)

species_mapping = {'setosa': 0, 'versicolor': 1, 'virginica': 2}
predicted_species_name = species_mapping[predicted_species[0]]
print("Predicted species:",predicted_species_name)
# Out:
# Predicted species: 2
# C:\Users\tiwar\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
